# %% [markdown]
# <h1>Regresion</h1>

# %% [markdown]
# <h2>Configuracion</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Cargo el dataset</h3>

# %%
#df = pd.read_csv('/Users/ezequieldjemdjemian/Documents/TP_FIUBA_Regresion/ventas.csv')
df = pd.read_csv('ventas.csv')

# %% [markdown]
# <h2>Analisis Exploratorio</h2>

# %% [markdown]
# <h3>Univariado</h3>

# %%
df.dtypes
# Out:
# fecha                   object
# lat                    float64
# lon                    float64
# L1                      object
# L2                      object
# L3                      object
# L4                      object
# operacion               object
# tipo                    object
# ambientes              float64
# habitaciones           float64
# baños                  float64
# superficie_total         int64
# superficie_cubierta      int64
# precio                   int64
# moneda                  object
# titulo                  object
# descripcion             object
# Precio/Metro           float64
# dtype: object

# %%
df.shape
# Out:
# (611393, 19)

# %%
df.describe()
# Out:
#                  lat            lon      ambientes   habitaciones  \
# count  550092.000000  550092.000000  482476.000000  401442.000000
# mean      -34.511908     -59.093122       3.075102       2.306904
# std         1.420251       2.036147       1.697239       2.009812
# min       -54.834711     -72.320946       1.000000      -2.000000
# 25%       -34.629023     -58.674273       2.000000       1.000000
# 50%       -34.592029     -58.471564       3.000000       2.000000
# 75%       -34.471672     -58.412171       4.000000       3.000000
# max       -22.050635     -53.647482      40.000000     900.000000
#
#                baños  superficie_total  superficie_cubierta        precio  \
# count  563811.000000     611393.000000        611393.000000  6.113930e+05
# mean        1.744689        313.020159           184.155098  2.465625e+05
# std         1.089957       2682.306784          2183.683567  3.035567e+05
# min         1.000000         10.000000             1.000000  5.000000e+03
# 25%         1.000000         51.000000            46.000000  9.500000e+04
# 50%         1.000000         90.000000            75.000000  1.570000e+05
# 75%         2.000000        210.000000           150.000000  2.800000e+05
# max        20.000000     200000.000000        430000.000000  3.990000e+06
#
#         Precio/Metro
# count  611393.000000
# mean     1946.520954
# std      1541.192435
# min         0.083333
# 25%      1100.000000
# 50%      1819.462963
# 75%      2575.757576
# max    240000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611393 entries, 0 to 611392
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fecha                611393 non-null  object
#  1   lat                  550092 non-null  float64
#  2   lon                  550092 non-null  float64
#  3   L1                   611393 non-null  object
#  4   L2                   611393 non-null  object
#  5   L3                   611393 non-null  object
#  6   L4                   201219 non-null  object
#  7   operacion            611393 non-null  object
#  8   tipo                 611393 non-null  object
#  9   ambientes            482476 non-null  float64
#  10  habitaciones         401442 non-null  float64
#  11  baños                563811 non-null  float64
#  12  superficie_total     611393 non-null  int64
#  13  superficie_cubierta  611393 non-null  int64
#  14  precio               611393 non-null  int64
#  15  moneda               611393 non-null  object
#  16  titulo               611393 non-null  object
#  17  descripcion          611383 non-null  object
#  18  Precio/Metro         611393 non-null  float64
# dtypes: float64(6), int64(3), object(10)
# memory usage: 88.6+ MB

# %% [markdown]
# <h2>Transformaciones</h2>

# %% [markdown]
# <h3>Renombrar columnas</h3>

# %%
#Renombro las columnas
df.rename(columns= {'L1':'Pais', 'L2':'Provincia', 'L3':'Ciudad', 'L4':'Barrio', 'baños':'banos'}, inplace=True)
df['fecha']=df['fecha'].astype('datetime64')

#elimino las columnas que no voy a utilizar en el modelo
#la columna moneda la voy a eliminar tambien, pues set(df['moneda'])={'USD'}
df.drop(columns=['titulo','descripcion', 'moneda'], inplace=True)
df.dtypes
# Out:
# fecha                  datetime64[ns]
# lat                           float64
# lon                           float64
# Pais                           object
# Provincia                      object
# Ciudad                         object
# Barrio                         object
# operacion                      object
# tipo                           object
# ambientes                     float64
# habitaciones                  float64
# banos                         float64
# superficie_total                int64
# superficie_cubierta             int64
# precio                          int64
# Precio/Metro                  float64
# dtype: object

# %%
df['Ciudad'] = df['Ciudad'].str.replace('á','a').str.replace('ñ','n').str.replace('ó','o').str.replace('í','i').str.replace('é','e')
df['Provincia']=df['Provincia'].str.replace('á','a').str.replace('ñ','n').str.replace('ó','o').str.replace('í','i').str.replace('é','e')
df['Provincia'].unique()
# Out:
# array(['Salta', 'Bs.As. G.B.A. Zona Norte', 'Bs.As. G.B.A. Zona Sur',
#        'Capital Federal', 'Santa Fe', 'Cordoba', 'Buenos Aires Interior',
#        'Bs.As. G.B.A. Zona Oeste', 'Neuquen',
#        'Buenos Aires Costa Atlantica', 'Rio Negro', 'Mendoza',
#        'Entre Rios', 'Chubut', 'Tucuman', 'San Juan', 'San Luis',
#        'Misiones', 'Santa Cruz', 'La Pampa', 'Corrientes', 'Chaco',
#        'Jujuy', 'La Rioja', 'Tierra Del Fuego', 'Santiago Del Estero',
#        'Catamarca', 'Formosa'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611393 entries, 0 to 611392
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fecha                611393 non-null  datetime64[ns]
#  1   lat                  550092 non-null  float64
#  2   lon                  550092 non-null  float64
#  3   Pais                 611393 non-null  object
#  4   Provincia            611393 non-null  object
#  5   Ciudad               611393 non-null  object
#  6   Barrio               201219 non-null  object
#  7   operacion            611393 non-null  object
#  8   tipo                 611393 non-null  object
#  9   ambientes            482476 non-null  float64
#  10  habitaciones         401442 non-null  float64
#  11  banos                563811 non-null  float64
#  12  superficie_total     611393 non-null  int64
#  13  superficie_cubierta  611393 non-null  int64
#  14  precio               611393 non-null  int64
#  15  Precio/Metro         611393 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(6)
# memory usage: 74.6+ MB

# %% [markdown]
# <h3>Missing values</h3>

# %%
df.isnull().sum()
# Out:
# fecha                       0
# lat                     61301
# lon                     61301
# Pais                        0
# Provincia                   0
# Ciudad                      0
# Barrio                 410174
# operacion                   0
# tipo                        0
# ambientes              128917
# habitaciones           209951
# banos                   47582
# superficie_total            0
# superficie_cubierta         0
# precio                      0
# Precio/Metro                0
# dtype: int64

# %% [markdown]
# <h4>Columnas con missing Values</h4>
# <ui>
# <li>latitud</li>
# <li>longitud</li>
# <li>ambientes</li>
# <li>habitaciones</li>
# <li>baños</li>
# <li>descripcion</li>
# </ui>

# %% [markdown]
# <h4>Dealing with missing values</h4>
# <ui>
# <li>1 - Eliminar columna</li>
# <li>2 - Eliminar registro</li>
# <li>3 - Imputar media</li>
# <li>4 - Imputar mediana</li>
# <li>5 - Imputar estimacion</li>
# </ui>

# %%
#opcion=1 -> elimina la columna 
#opcion=2 -> elimina el registro
#opcion=3 -> asigna la media muestral
#opcion=4 -> asigna la mediana
opcion = 4
#df = pd.read_csv('ventas.csv')
if opcion == 1 :
    df.dropna(axis=1, inplace=True)
if opcion == 2 :
    df.dropna(axis=0, inplace=True)
if opcion == 3 : 
    df['ambientes'] = df['ambientes'].fillna(df['ambientes'].mean())
    df['habitaciones'] = df['habitaciones'].fillna(df['habitaciones'].mean())
    df['banos'] = df['banos'].fillna(df['banos'].mean())
    #vamos a realizar la imputacion para las columnas 'lat' y 'lon', imputando el promedio de calculado para cada ciudad. Es decir, si existiese un registro con 'lat' y 'lon' con missing value para la 'Ciudad' = 'Achiras', 
    # a ese registro le imputaremos el promedio de las coordenadas, obtenidos a partir de nuestra muestra, pero calculada sobre 'Ciudad' = 'Achiras'.

    #creo el dataframe con los promedios de latitud y longitud por ciudad
    coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].mean()
    coordenadas_mean_by_ciudad.rename(columns={'lat':'latitud' , 'lon':'longitud'}, inplace=True)

    #del df original, me quedo con aquellos registros que no tienen latitud ni longitud, y en donce la ciudad no es nula
    df_sin_coordenadas = df[(df['lat'].isnull() | df['lon'].isnull() ) &  (df['Ciudad'].isnull()==False)] 


    #joineo los promedios de lat y long por ciudad, junto con el subconjunto del dataset que no tiene lat ni long
    subconjunto = df_sin_coordenadas.join(coordenadas_mean_by_ciudad.set_index('Ciudad'), on='Ciudad')
    subconjunto.drop(columns = ['lat','lon'], inplace=True)

    #renombro las columnas del conjunto original, y borro los registros nulos para esos registros
    conjunto_original = df.rename(columns={'lat':'latitud' , 'lon':'longitud'})
    conjunto_original.dropna(subset=['latitud','longitud'], inplace=True)

    df = conjunto_original.append(subconjunto)

    #finalmente renombro las columnas como 'lat' y 'lon'
    df.rename(columns={'latitud':'lat', 'longitud':'lon'}, inplace=True)
if opcion == 4:
    df['ambientes'] = df['ambientes'].fillna(df['ambientes'].median())
    df['habitaciones'] = df['habitaciones'].fillna(df['habitaciones'].median())
    df['banos'] = df['banos'].fillna(df['banos'].median())
    #vamos a realizar la imputacion para las columnas 'lat' y 'lon', imputando el promedio de calculado para cada ciudad. Es decir, si existiese un registro con 'lat' y 'lon' con missing value para la 'Ciudad' = 'Achiras', 
    # a ese registro le imputaremos el promedio de las coordenadas, obtenidos a partir de nuestra muestra, pero calculada sobre 'Ciudad' = 'Achiras'.

    #creo el dataframe con los promedios de latitud y longitud por ciudad
    coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].median()
    coordenadas_mean_by_ciudad.rename(columns={'lat':'latitud' , 'lon':'longitud'}, inplace=True)

    #del df original, me quedo con aquellos registros que no tienen latitud ni longitud, y en donce la ciudad no es nula
    df_sin_coordenadas = df[(df['lat'].isnull() | df['lon'].isnull() ) &  (df['Ciudad'].isnull()==False)] 


    #joineo los promedios de lat y long por ciudad, junto con el subconjunto del dataset que no tiene lat ni long
    subconjunto = df_sin_coordenadas.join(coordenadas_mean_by_ciudad.set_index('Ciudad'), on='Ciudad')
    subconjunto.drop(columns = ['lat','lon'], inplace=True)

    #renombro las columnas del conjunto original, y borro los registros nulos para esos registros
    conjunto_original = df.rename(columns={'lat':'latitud' , 'lon':'longitud'})
    conjunto_original.dropna(subset=['latitud','longitud'], inplace=True)

    df = conjunto_original.append(subconjunto)

    #finalmente renombro las columnas como 'lat' y 'lon'
    df.rename(columns={'latitud':'lat', 'longitud':'lon'}, inplace=True)
# Out:
# /var/folders/4c/7qb0mfh53bv_v1d5dzbvspgh0000gn/T/ipykernel_1192/2479462617.py:42: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].mode()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4c/7qb0mfh53bv_v1d5dzbvspgh0000gn/T/ipykernel_1192/2479462617.py in <module>
#      40
#      41     #creo el dataframe con los promedios de latitud y longitud por ciudad
# ---> 42     coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].mode()
#      43     coordenadas_mean_by_ciudad.rename(columns={'lat':'latitud' , 'lon':'longitud'}, inplace=True)
#      44
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'mode'

# %%
#vamos a realizar la imputacion para las columnas 'lat' y 'lon', imputando el promedio de calculado para cada ciudad. Es decir, si existiese un registro con 'lat' y 'lon' con missing value para la 'Ciudad' = 'Achiras', 
# a ese registro le imputaremos el promedio de las coordenadas, obtenidos a partir de nuestra muestra, pero calculada sobre 'Ciudad' = 'Achiras'.

#creo el dataframe con los promedios de latitud y longitud por ciudad
'''coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].mean()
coordenadas_mean_by_ciudad.rename(columns={'lat':'latitud' , 'lon':'longitud'}, inplace=True)

#del df original, me quedo con aquellos registros que no tienen latitud ni longitud, y en donce la ciudad no es nula
df_sin_coordenadas = df[(df['lat'].isnull() | df['lon'].isnull() ) &  (df['Ciudad'].isnull()==False)] 


#joineo los promedios de lat y long por ciudad, junto con el subconjunto del dataset que no tiene lat ni long
subconjunto = df_sin_coordenadas.join(coordenadas_mean_by_ciudad.set_index('Ciudad'), on='Ciudad')
subconjunto.drop(columns = ['lat','lon'], inplace=True)

#renombro las columnas del conjunto original, y borro los registros nulos para esos registros
conjunto_original = df.rename(columns={'lat':'latitud' , 'lon':'longitud'})
conjunto_original.dropna(subset=['latitud','longitud'], inplace=True)

df = conjunto_original.append(subconjunto)

#finalmente renombro las columnas como 'lat' y 'lon'
df.rename(columns={'latitud':'lat', 'longitud':'lon'}, inplace=True)

df.info()'''
# Out:
# /var/folders/4c/7qb0mfh53bv_v1d5dzbvspgh0000gn/T/ipykernel_1192/1561173244.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   coordenadas_mean_by_ciudad = df.groupby(['Ciudad'], as_index=False)['lat','lon'].mean()
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611393 entries, 0 to 611313
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fecha                611393 non-null  datetime64[ns]
#  1   lat                  610961 non-null  float64
#  2   lon                  610961 non-null  float64
#  3   Pais                 611393 non-null  object
#  4   Provincia            611393 non-null  object
#  5   Ciudad               611393 non-null  object
#  6   Barrio               201219 non-null  object
#  7   operacion            611393 non-null  object
#  8   tipo                 611393 non-null  object
#  9   ambientes            611393 non-null  float64
#  10  habitaciones         611393 non-null  float64
#  11  banos                611393 non-null  float64
#  12  superficie_total     611393 non-null  int64
#  13  superficie_cubierta  611393 non-null  int64
#  14  precio               611393 non-null  int64
#  15  moneda               611393 non-null  object
#  16  titulo               611393 non-null  object
#  17  descripcion          611383 non-null  object
#  18  Precio/Metro         611393 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(9)
# memory usage: 93.3+ MB

# %% [markdown]
# df

# %%
df
# Out:
#             fecha        lat        lon       Pais               Provincia  \
# 0      2019-09-29 -24.762622 -65.337180  Argentina                   Salta
# 2      2019-09-29 -34.878619 -58.082626  Argentina  Bs.As. G.B.A. Zona Sur
# 3      2019-09-29 -34.638380 -58.514443  Argentina         Capital Federal
# 4      2019-09-29 -34.640410 -58.466927  Argentina         Capital Federal
# 5      2019-09-29 -34.608526 -58.431002  Argentina         Capital Federal
# ...           ...        ...        ...        ...                     ...
# 611306 2019-07-31 -41.142449 -71.325060  Argentina               Rio Negro
# 611307 2019-07-31 -41.142449 -71.325060  Argentina               Rio Negro
# 611310 2019-07-31 -41.142449 -71.325060  Argentina               Rio Negro
# 611311 2019-07-31 -41.142449 -71.325060  Argentina               Rio Negro
# 611313 2019-07-31 -41.142449 -71.325060  Argentina               Rio Negro
#
#                          Ciudad                   Barrio operacion  \
# 0                         Salta                      NaN     Venta
# 2                      La Plata                City Bell     Venta
# 3                    Villa Luro                      NaN     Venta
# 4                        Flores                      NaN     Venta
# 5                       Almagro                      NaN     Venta
# ...                         ...                      ...       ...
# 611306  San Carlos de Bariloche  San Carlos de Bariloche     Venta
# 611307  San Carlos de Bariloche  San Carlos de Bariloche     Venta
# 611310  San Carlos de Bariloche  San Carlos de Bariloche     Venta
# 611311  San Carlos de Bariloche  San Carlos de Bariloche     Venta
# 611313  San Carlos de Bariloche  San Carlos de Bariloche     Venta
#
#                    tipo  ambientes  habitaciones     banos  superficie_total  \
# 0                  Casa   3.000000      2.306904  1.744689              3500
# 2                    PH   4.000000      2.306904  1.744689               310
# 3                    PH   3.000000      2.306904  1.744689                80
# 4                    PH   2.000000      2.306904  1.000000                95
# 5          Departamento   2.000000      2.306904  1.000000                40
# ...                 ...        ...           ...       ...               ...
# 611306     Departamento   3.000000      2.000000  2.000000               127
# 611307     Departamento   2.000000      1.000000  1.000000                85
# 611310     Departamento   2.000000      1.000000  1.000000                91
# 611311     Departamento   3.000000      2.000000  2.000000                86
# 611313  Local comercial   3.075102      2.306904  1.000000                55
#
#         superficie_cubierta  precio moneda  \
# 0                       250  265000    USD
# 2                        97  180000    USD
# 3                        65   89000    USD
# 4                        40  115000    USD
# 5                        40   83000    USD
# ...                     ...     ...    ...
# 611306                   80  328606    USD
# 611307                   74  396852    USD
# 611310                   73  354459    USD
# 611311                   75  225660    USD
# 611313                   55  330000    USD
#
#                                                    titulo  \
# 0                                              Casa venta
# 2                                                Ph venta
# 3                                                Ph venta
# 4       HERMOSO PH RECIEN RECICLADO A UNA CUADRA DE SU...
# 5                                  Departamento - Almagro
# ...                                                   ...
# 611306  Venta - 3 ambientes en barrio cerrado - Barran...
# 611307                    Venta - Bustillo Av. Km 1 10º F
# 611310                     Venta - Bustillo Av. Km 1 1º G
# 611311  Venta - 3 ambientes en barrio cerrado - Barran...
# 611313  EXCELENTE LOCAL EN  EL PASEO DE LA CATEDRAL, B...
#
#                                               descripcion  Precio/Metro
# 0       Casa a estrenar en 2 plantas. 3 dormitorios, u...     75.714286
# 2       Hermoso duplex ubicado en barrio parque ecológ...    580.645161
# 3       Liniers, Yerbal al 6300 a una cuadra de Rivada...   1112.500000
# 4       INCREIBLE OPORTUNIDAD!! RECIEN RECICLADO<br>Ve...   1210.526316
# 5       Hermoso dos ambientes reciclado a nuevo, super...   2075.000000
# ...                                                   ...           ...
# 611306  Living-comedor con cocina, salida a balcón con...   2587.448819
# 611307  Departamento. Living/Comedor. 1 dormitorio(s)....   4668.847059
# 611310  Departamento. Comedor. 1 dormitorio(s). 1 baño...   3895.153846
# 611311  Living-comedor con cocina, salida a balcón con...   2623.953488
# 611313  Local de 55m2 de dos plantas con doble vidrier...   6000.000000
#
# [611393 rows x 19 columns]
